# %%
import xarray as xr
import pandas as pd

import adriaClimIndUtils_aggregates as pv

# %%
pv.acGenerate1DFixDimCSV
# Out:
# <function adriaClimIndUtils_aggregates.acGenerate1DFixDimCSV(fy_1D, NcFile1DoutputCSV)>

# %%
pv.acGenerate1DFixDim
# Out:
# <function adriaClimIndUtils_aggregates.acGenerate1DFixDim(t, NcFile1Doutput)>

# %%
import adriaClimIndUtils_plots as pv1

# %%
ncRawDataFileName1 = "CMEMS_SST_clipped.nc"

# %%
rawData1 = xr.open_dataset(ncRawDataFileName1)

# %%
NcFile1Doutput = "CMEMS_SST_clipped_1D_FIXED_DIM.nc"

# %%
clippedfix1Tendency=pv1.acGenerate1DTendency(rawData1,NcFile1Doutput)
# Out:
# No handles with labels found to put in legend.

# %%
NcFile1DoutputCSV= "CMEMS_SST_clipped_1D_FIXED_DIM.csv"

# %%
ts=pv1.acGenerateDailyTimeSeries(NcFile1DoutputCSV)

# %%
ts1=pv1.acGenerateDailyTimeSeriesSTD(NcFile1DoutputCSV)

# %%
ts2=pv1.acGenerateDailyTimeSeriesPLOT(NcFile1DoutputCSV)
